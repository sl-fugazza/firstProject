# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
import requests


# esercizio API - dati EIA

# %%
myAPI_EIA = "POyslk9n6CPJZ0d9wWBN8XBYRCuKnmcPw631972y"
url1 = f"https://api.eia.gov/v2/seds/data/?frequency=annual&data[0]=value&start=1960&length=5000&api_key={myAPI_EIA}"
#url2 = f"https://api.eia.gov/v2/crude-oil-imports/data/?frequency=annual&data[0]=quantity&start=2009&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000&api_key={myAPI_EIA}"

response = requests.get(url1)
data = response.json()

df = pd.DataFrame(data['response']['data'])

# %%
print(df.columns)

df.head()
# Out:
# Index(['period', 'seriesId', 'seriesDescription', 'stateId',
#        'stateDescription', 'value', 'unit'],
#       dtype='object')
#   period seriesId                                  seriesDescription stateId  \
# 0   2024    AVACB  Aviation gasoline consumed by the transportati...      AK
# 1   2024    AVACB  Aviation gasoline consumed by the transportati...      AL
# 2   2024    AVACB  Aviation gasoline consumed by the transportati...      AR
# 3   2024    AVACB  Aviation gasoline consumed by the transportati...      AZ
# 4   2024    AVACB  Aviation gasoline consumed by the transportati...      CA
#
#   stateDescription value         unit
# 0           Alaska  1096  Billion Btu
# 1          Alabama   390  Billion Btu
# 2         Arkansas   259  Billion Btu
# 3          Arizona   895  Billion Btu
# 4       California  2082  Billion Btu

# %%
# sql
import sqlite3
print(sqlite3.sqlite_version)
# Out:
# 3.45.1
