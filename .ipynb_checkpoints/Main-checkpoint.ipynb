# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
import requests


# esercizio API - dati EIA

# %%
myAPI_EIA = "POyslk9n6CPJZ0d9wWBN8XBYRCuKnmcPw631972y"
url1 = f"https://api.eia.gov/v2/seds/data/?frequency=annual&data[0]=value&start=1960&length=5000&api_key={myAPI_EIA}"
#url2 = f"https://api.eia.gov/v2/crude-oil-imports/data/?frequency=annual&data[0]=quantity&start=2009&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000&api_key={myAPI_EIA}"

response = requests.get(url1)
data = response.json()

df = pd.DataFrame(data['response']['data'])
#   ,dtype={'StateId': pd.StringDtype()})
df
# Out:
#      period seriesId                                  seriesDescription  \
# 0      2024    AVACB  Aviation gasoline consumed by the transportati...
# 1      2024    AVACB  Aviation gasoline consumed by the transportati...
# 2      2024    AVACB  Aviation gasoline consumed by the transportati...
# 3      2024    AVACB  Aviation gasoline consumed by the transportati...
# 4      2024    AVACB  Aviation gasoline consumed by the transportati...
# ...     ...      ...                                                ...
# 4995   2024    CLHCK  Factor for converting coal consumed by the res...
# 4996   2024    CLHCK  Factor for converting coal consumed by the res...
# 4997   2024    CLHCK  Factor for converting coal consumed by the res...
# 4998   2024    CLHCK  Factor for converting coal consumed by the res...
# 4999   2024    CLHCK  Factor for converting coal consumed by the res...
#
#      stateId stateDescription value                       unit
# ...

# %%
df['seriesDescription'] = df['seriesDescription'].astype(pd.StringDtype())
df['value'] = pd.to_numeric(df['value'])
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   period             5000 non-null   object
#  1   seriesId           5000 non-null   object
#  2   seriesDescription  5000 non-null   string
#  3   stateId            5000 non-null   object
#  4   stateDescription   5000 non-null   object
#  5   value              5000 non-null   float64
#  6   unit               5000 non-null   object
# dtypes: float64(1), object(5), string(1)
# memory usage: 273.6+ KB
# None

# %%
#print(df.columns)

#df.head(30)

#df.describe()
#df.loc[1,"seriesDescription"]

df.groupby('seriesDescription')["value"].sum()
# Out:
# seriesDescription
# Aviation gasoline average price, all end-use sectors                                        1622.31
# Aviation gasoline average price, all sectors                                                1622.31
# Aviation gasoline consumed by the transportation sector                                    54562.00
# Aviation gasoline expenditures in the transportation sector                                 1448.60
# Aviation gasoline price in the transportation sector                                        1622.31
#                                                                                             ...
# Renewable diesel product supplied portion to the transportation sector                   1082654.00
# Renewable diesel refinery and blender net inputs                                           52433.00
# Renewable diesel refinery and blender net inputs portion to the transportation sector      52433.00
# ...
